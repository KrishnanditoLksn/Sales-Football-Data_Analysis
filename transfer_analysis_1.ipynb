# %%
import pandas as pd
import  os
import  glob

path = r'D:\NUMPY\DATASET\FOOTBALL'
filenames = glob.glob(path + "/*.csv")
df = []

for file in filenames:
    df.append(pd.read_csv(file))

data_Ball = pd.concat( df,axis=0, ignore_index=True)
data_Ball.to_csv('transfer_data.csv')
data_Ball
# Out:
#         appearance_id  game_id  player_id  player_club_id
# 0           -1_172127     -1.0   172127.0          3999.0  \
# 1           -1_210988     -1.0   210988.0          3999.0
# 2           -1_231471     -1.0   231471.0          3999.0
# 3           -1_256819     -1.0   256819.0          3999.0
# 4           -1_281919     -1.0   281919.0          3999.0
# ...               ...      ...        ...             ...
# 2364022           NaN      NaN   158071.0             NaN
# 2364023           NaN      NaN   187191.0             NaN
# 2364024           NaN      NaN   279110.0             NaN
# 2364025           NaN      NaN   863829.0             NaN
# 2364026           NaN      NaN   405676.0             NaN
#
#          player_current_club_id        date             player_name
# 0                        3999.0         NaN                 Tyronne  \
# 1                         553.0         NaN  Christos Eleftheriadis
# ...
